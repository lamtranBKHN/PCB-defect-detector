# %% [markdown]
# <a href="https://colab.research.google.com/github/lamtranBKHN/PCB-defect-detector/blob/master/(224%2C224%2C3)VGG16_5600dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from imutils import paths
from keras.applications import VGG16
from keras.applications import imagenet_utils
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import load_img
from keras.optimizers import SGD
from keras.optimizers import RMSprop
from keras.layers import Input
from keras.models import Model
from keras.models import Sequential
from keras.layers.core import Dense
from keras.layers.core import Dropout
from keras.layers.core import Flatten
import numpy as np
import random
import os
from matplotlib import pyplot
from PIL import Image
from numpy import asarray
from matplotlib import pyplot as plt
import cv2
import pickle
# Out:
# Using TensorFlow backend.

# %%
IMG_SIZE = 80

file_list = []
class_list = []

DATADIR = "Organized dataSet"

# All the categories neural network will detect
CATEGORIES = ["mouse bite","not","open","pin hole",
              "short","spur","spurious copper"]

# Checking or all images in the data folder
for category in CATEGORIES :
    path = os.path.join(DATADIR, category)
    for img in os.listdir(path):
        img_array = cv2.imread(os.path.join(path, img), cv2.IMREAD_COLOR)

training_data = []

def create_training_data():
    for category in CATEGORIES :
        path = os.path.join(DATADIR, category)
        class_num = CATEGORIES.index(category)
        for img in os.listdir(path):
            try :
                img_array = cv2.imread(os.path.join(path, img), cv2.IMREAD_COLOR)
                new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
                training_data.append([new_array, class_num])
            except Exception as e:
                pass

create_training_data()
random.shuffle(training_data)

X = [] #features
y = [] #labels

for features, label in training_data:
    X.append(features)
    y.append(label)
    
X = np.array(X).reshape(-1, IMG_SIZE, IMG_SIZE, 3)   
# Creating the files containing all the information about your model
pickle_out = open("X.pickle", "wb")
pickle.dump(X, pickle_out)
pickle_out.close()

pickle_out = open("y.pickle", "wb")
pickle.dump(y, pickle_out)
pickle_out.close()

pickle_in = open("X.pickle", "rb")
X = pickle.load(pickle_in)

# Opening the files about data
X = pickle.load(open("X.pickle", "rb"))
y = pickle.load(open("y.pickle", "rb"))

# normalizing data (a pixel goes from 0 to 255)
X = X/255.0

# %%
# Load model VGG 16 
baseModel = VGG16(weights='imagenet', include_top=False, \
                  input_tensor=Input(shape=(IMG_SIZE, IMG_SIZE, 3)))
# Buil layer
fcHead = baseModel.output
# Flatten 
fcHead = Flatten()(fcHead)
# Add FC
fcHead = Dense(512, activation='relu')(fcHead)
fcHead = Dropout(0.3)(fcHead)
# Output layer with softmax activation
fcHead = Dense(7, activation='softmax')(fcHead)
# modle
model = model = Model(inputs=baseModel.input, outputs=fcHead)

# %%
model.compile(loss = "sparse_categorical_crossentropy", 
                    optimizer = SGD(lr=1e-5, momentum=0.9), 
                    metrics=["accuracy"])
# Training the model.
X = np.array(X)
y = np.array(y)
history = model.fit(X, y, batch_size=32, epochs=150, validation_split=0.1)

# Saving the model
model_json = model.to_json()
with open("model.json", "w") as json_file :
    json_file.write(model_json)

model.save_weights("model2.h5")
print("Saved model to disk")

model.save('CNN2.model')

# Printing a graph showing the accuracy changes during the training phase
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'b', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()
# Out:
# Train on 5040 samples, validate on 560 samples
# Epoch 1/150
# 5040/5040 [==============================] - 31s 6ms/step - loss: 1.9166 - accuracy: 0.2480 - val_loss: 1.6224 - val_accuracy: 0.4411
# Epoch 2/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 1.5560 - accuracy: 0.4165 - val_loss: 1.2877 - val_accuracy: 0.6536
# Epoch 3/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 1.2453 - accuracy: 0.5633 - val_loss: 0.9863 - val_accuracy: 0.7411
# Epoch 4/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.9870 - accuracy: 0.6558 - val_loss: 0.7338 - val_accuracy: 0.7982
# Epoch 5/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.7376 - accuracy: 0.7556 - val_loss: 0.5409 - val_accuracy: 0.8411
# Epoch 6/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.5736 - accuracy: 0.8099 - val_loss: 0.4230 - val_accuracy: 0.8625
# Epoch 7/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.4731 - accuracy: 0.8399 - val_loss: 0.3530 - val_accuracy: 0.8875
# Epoch 8/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.3988 - accuracy: 0.8681 - val_loss: 0.3033 - val_accuracy: 0.9089
# Epoch 9/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.3320 - accuracy: 0.8925 - val_loss: 0.2692 - val_accuracy: 0.9196
# Epoch 10/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.3046 - accuracy: 0.9010 - val_loss: 0.2459 - val_accuracy: 0.9268
# Epoch 11/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.2661 - accuracy: 0.9131 - val_loss: 0.2276 - val_accuracy: 0.9357
# Epoch 12/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.2413 - accuracy: 0.9216 - val_loss: 0.2062 - val_accuracy: 0.9393
# Epoch 13/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.2108 - accuracy: 0.9337 - val_loss: 0.1976 - val_accuracy: 0.9375
# Epoch 14/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.1992 - accuracy: 0.9345 - val_loss: 0.1915 - val_accuracy: 0.9429
# Epoch 15/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.1857 - accuracy: 0.9468 - val_loss: 0.1763 - val_accuracy: 0.9482
# Epoch 16/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.1739 - accuracy: 0.9460 - val_loss: 0.1697 - val_accuracy: 0.9500
# Epoch 17/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.1627 - accuracy: 0.9512 - val_loss: 0.1704 - val_accuracy: 0.9518
# Epoch 18/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.1541 - accuracy: 0.9520 - val_loss: 0.1625 - val_accuracy: 0.9571
# Epoch 19/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.1340 - accuracy: 0.9617 - val_loss: 0.1551 - val_accuracy: 0.9589
# Epoch 20/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.1334 - accuracy: 0.9583 - val_loss: 0.1535 - val_accuracy: 0.9571
# Epoch 21/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.1202 - accuracy: 0.9623 - val_loss: 0.1567 - val_accuracy: 0.9554
# Epoch 22/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.1136 - accuracy: 0.9667 - val_loss: 0.1479 - val_accuracy: 0.9589
# Epoch 23/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0994 - accuracy: 0.9724 - val_loss: 0.1529 - val_accuracy: 0.9571
# Epoch 24/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.1048 - accuracy: 0.9683 - val_loss: 0.1423 - val_accuracy: 0.9625
# Epoch 25/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0977 - accuracy: 0.9740 - val_loss: 0.1444 - val_accuracy: 0.9554
# Epoch 26/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0922 - accuracy: 0.9742 - val_loss: 0.1415 - val_accuracy: 0.9625
# Epoch 27/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0883 - accuracy: 0.9744 - val_loss: 0.1363 - val_accuracy: 0.9589
# Epoch 28/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0878 - accuracy: 0.9734 - val_loss: 0.1385 - val_accuracy: 0.9589
# Epoch 29/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0798 - accuracy: 0.9788 - val_loss: 0.1397 - val_accuracy: 0.9589
# Epoch 30/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0781 - accuracy: 0.9772 - val_loss: 0.1280 - val_accuracy: 0.9661
# Epoch 31/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0742 - accuracy: 0.9792 - val_loss: 0.1331 - val_accuracy: 0.9625
# Epoch 32/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0739 - accuracy: 0.9800 - val_loss: 0.1262 - val_accuracy: 0.9661
# Epoch 33/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0629 - accuracy: 0.9827 - val_loss: 0.1276 - val_accuracy: 0.9643
# Epoch 34/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0643 - accuracy: 0.9827 - val_loss: 0.1266 - val_accuracy: 0.9679
# Epoch 35/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0675 - accuracy: 0.9815 - val_loss: 0.1247 - val_accuracy: 0.9643
# Epoch 36/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0576 - accuracy: 0.9841 - val_loss: 0.1232 - val_accuracy: 0.9643
# Epoch 37/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0556 - accuracy: 0.9855 - val_loss: 0.1319 - val_accuracy: 0.9607
# Epoch 38/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0610 - accuracy: 0.9821 - val_loss: 0.1258 - val_accuracy: 0.9679
# Epoch 39/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0555 - accuracy: 0.9857 - val_loss: 0.1237 - val_accuracy: 0.9643
# Epoch 40/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0496 - accuracy: 0.9867 - val_loss: 0.1208 - val_accuracy: 0.9679
# Epoch 41/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0479 - accuracy: 0.9869 - val_loss: 0.1159 - val_accuracy: 0.9696
# Epoch 42/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0470 - accuracy: 0.9879 - val_loss: 0.1175 - val_accuracy: 0.9696
# Epoch 43/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0492 - accuracy: 0.9857 - val_loss: 0.1264 - val_accuracy: 0.9679
# Epoch 44/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0467 - accuracy: 0.9853 - val_loss: 0.1164 - val_accuracy: 0.9661
# Epoch 45/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0427 - accuracy: 0.9891 - val_loss: 0.1148 - val_accuracy: 0.9696
# Epoch 46/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0418 - accuracy: 0.9869 - val_loss: 0.1193 - val_accuracy: 0.9661
# Epoch 47/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0428 - accuracy: 0.9881 - val_loss: 0.1118 - val_accuracy: 0.9714
# Epoch 48/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0433 - accuracy: 0.9881 - val_loss: 0.1153 - val_accuracy: 0.9696
# Epoch 49/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0372 - accuracy: 0.9899 - val_loss: 0.1159 - val_accuracy: 0.9732
# Epoch 50/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0367 - accuracy: 0.9903 - val_loss: 0.1119 - val_accuracy: 0.9714
# Epoch 51/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0365 - accuracy: 0.9893 - val_loss: 0.1170 - val_accuracy: 0.9696
# Epoch 52/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0368 - accuracy: 0.9883 - val_loss: 0.1150 - val_accuracy: 0.9696
# Epoch 53/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0341 - accuracy: 0.9907 - val_loss: 0.1116 - val_accuracy: 0.9714
# Epoch 54/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0358 - accuracy: 0.9889 - val_loss: 0.1162 - val_accuracy: 0.9696
# Epoch 55/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0362 - accuracy: 0.9891 - val_loss: 0.1167 - val_accuracy: 0.9679
# Epoch 56/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0303 - accuracy: 0.9929 - val_loss: 0.1127 - val_accuracy: 0.9679
# Epoch 57/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0283 - accuracy: 0.9935 - val_loss: 0.1098 - val_accuracy: 0.9714
# Epoch 58/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0300 - accuracy: 0.9915 - val_loss: 0.1103 - val_accuracy: 0.9750
# Epoch 59/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0280 - accuracy: 0.9919 - val_loss: 0.1062 - val_accuracy: 0.9732
# Epoch 60/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0248 - accuracy: 0.9933 - val_loss: 0.1208 - val_accuracy: 0.9661
# Epoch 61/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0285 - accuracy: 0.9929 - val_loss: 0.1173 - val_accuracy: 0.9696
# Epoch 62/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0271 - accuracy: 0.9923 - val_loss: 0.1123 - val_accuracy: 0.9732
# Epoch 63/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0255 - accuracy: 0.9937 - val_loss: 0.1155 - val_accuracy: 0.9679
# Epoch 64/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0284 - accuracy: 0.9915 - val_loss: 0.1130 - val_accuracy: 0.9661
# Epoch 65/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0229 - accuracy: 0.9937 - val_loss: 0.1101 - val_accuracy: 0.9732
# Epoch 66/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0210 - accuracy: 0.9942 - val_loss: 0.1123 - val_accuracy: 0.9750
# Epoch 67/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0205 - accuracy: 0.9940 - val_loss: 0.1091 - val_accuracy: 0.9750
# Epoch 68/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0237 - accuracy: 0.9935 - val_loss: 0.1056 - val_accuracy: 0.9732
# Epoch 69/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0270 - accuracy: 0.9925 - val_loss: 0.1138 - val_accuracy: 0.9714
# Epoch 70/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0229 - accuracy: 0.9933 - val_loss: 0.1196 - val_accuracy: 0.9679
# Epoch 71/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0193 - accuracy: 0.9956 - val_loss: 0.1139 - val_accuracy: 0.9679
# Epoch 72/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0157 - accuracy: 0.9966 - val_loss: 0.1077 - val_accuracy: 0.9714
# Epoch 73/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0209 - accuracy: 0.9950 - val_loss: 0.1100 - val_accuracy: 0.9714
# Epoch 74/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0183 - accuracy: 0.9948 - val_loss: 0.1103 - val_accuracy: 0.9750
# Epoch 75/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0172 - accuracy: 0.9964 - val_loss: 0.1090 - val_accuracy: 0.9714
# Epoch 76/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0170 - accuracy: 0.9950 - val_loss: 0.1042 - val_accuracy: 0.9786
# Epoch 77/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0176 - accuracy: 0.9952 - val_loss: 0.1118 - val_accuracy: 0.9696
# Epoch 78/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0172 - accuracy: 0.9962 - val_loss: 0.1153 - val_accuracy: 0.9661
# Epoch 79/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0201 - accuracy: 0.9942 - val_loss: 0.1070 - val_accuracy: 0.9768
# Epoch 80/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0139 - accuracy: 0.9962 - val_loss: 0.1132 - val_accuracy: 0.9696
# Epoch 81/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0213 - accuracy: 0.9935 - val_loss: 0.1106 - val_accuracy: 0.9714
# Epoch 82/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0201 - accuracy: 0.9946 - val_loss: 0.1091 - val_accuracy: 0.9732
# Epoch 83/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0157 - accuracy: 0.9962 - val_loss: 0.1073 - val_accuracy: 0.9714
# Epoch 84/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0180 - accuracy: 0.9948 - val_loss: 0.1102 - val_accuracy: 0.9732
# Epoch 85/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0162 - accuracy: 0.9966 - val_loss: 0.1119 - val_accuracy: 0.9714
# Epoch 86/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0159 - accuracy: 0.9958 - val_loss: 0.1098 - val_accuracy: 0.9714
# Epoch 87/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0164 - accuracy: 0.9966 - val_loss: 0.1096 - val_accuracy: 0.9714
# Epoch 88/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0155 - accuracy: 0.9954 - val_loss: 0.1108 - val_accuracy: 0.9696
# Epoch 89/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0144 - accuracy: 0.9964 - val_loss: 0.1043 - val_accuracy: 0.9732
# Epoch 90/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0137 - accuracy: 0.9964 - val_loss: 0.1108 - val_accuracy: 0.9679
# Epoch 91/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0156 - accuracy: 0.9962 - val_loss: 0.1136 - val_accuracy: 0.9714
# Epoch 92/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0122 - accuracy: 0.9960 - val_loss: 0.1121 - val_accuracy: 0.9750
# Epoch 93/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0164 - accuracy: 0.9950 - val_loss: 0.1106 - val_accuracy: 0.9696
# Epoch 94/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0149 - accuracy: 0.9950 - val_loss: 0.1102 - val_accuracy: 0.9732
# Epoch 95/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0126 - accuracy: 0.9956 - val_loss: 0.1084 - val_accuracy: 0.9714
# Epoch 96/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0114 - accuracy: 0.9978 - val_loss: 0.1113 - val_accuracy: 0.9696
# Epoch 97/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0156 - accuracy: 0.9960 - val_loss: 0.1158 - val_accuracy: 0.9696
# Epoch 98/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0121 - accuracy: 0.9970 - val_loss: 0.1105 - val_accuracy: 0.9714
# Epoch 99/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0135 - accuracy: 0.9964 - val_loss: 0.1055 - val_accuracy: 0.9768
# Epoch 100/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0109 - accuracy: 0.9974 - val_loss: 0.1178 - val_accuracy: 0.9679
# Epoch 101/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0126 - accuracy: 0.9958 - val_loss: 0.1097 - val_accuracy: 0.9732
# Epoch 102/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0106 - accuracy: 0.9966 - val_loss: 0.1108 - val_accuracy: 0.9768
# Epoch 103/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0094 - accuracy: 0.9976 - val_loss: 0.1082 - val_accuracy: 0.9750
# Epoch 104/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0109 - accuracy: 0.9972 - val_loss: 0.1142 - val_accuracy: 0.9714
# Epoch 105/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0136 - accuracy: 0.9954 - val_loss: 0.1157 - val_accuracy: 0.9661
# Epoch 106/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0094 - accuracy: 0.9978 - val_loss: 0.1114 - val_accuracy: 0.9732
# Epoch 107/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0101 - accuracy: 0.9974 - val_loss: 0.1119 - val_accuracy: 0.9750
# Epoch 108/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0108 - accuracy: 0.9976 - val_loss: 0.1038 - val_accuracy: 0.9750
# Epoch 109/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0118 - accuracy: 0.9970 - val_loss: 0.1080 - val_accuracy: 0.9768
# Epoch 110/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0118 - accuracy: 0.9968 - val_loss: 0.1186 - val_accuracy: 0.9732
# Epoch 111/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0126 - accuracy: 0.9970 - val_loss: 0.1086 - val_accuracy: 0.9750
# Epoch 112/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0096 - accuracy: 0.9974 - val_loss: 0.1197 - val_accuracy: 0.9696
# Epoch 113/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0110 - accuracy: 0.9976 - val_loss: 0.1114 - val_accuracy: 0.9714
# Epoch 114/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0082 - accuracy: 0.9982 - val_loss: 0.1170 - val_accuracy: 0.9732
# Epoch 115/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0105 - accuracy: 0.9974 - val_loss: 0.1172 - val_accuracy: 0.9696
# Epoch 116/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0099 - accuracy: 0.9978 - val_loss: 0.1168 - val_accuracy: 0.9732
# Epoch 117/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0093 - accuracy: 0.9972 - val_loss: 0.1129 - val_accuracy: 0.9750
# Epoch 118/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0086 - accuracy: 0.9982 - val_loss: 0.1160 - val_accuracy: 0.9732
# Epoch 119/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0085 - accuracy: 0.9980 - val_loss: 0.1136 - val_accuracy: 0.9696
# Epoch 120/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0087 - accuracy: 0.9982 - val_loss: 0.1163 - val_accuracy: 0.9714
# Epoch 121/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0108 - accuracy: 0.9972 - val_loss: 0.1123 - val_accuracy: 0.9732
# Epoch 122/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0080 - accuracy: 0.9982 - val_loss: 0.1108 - val_accuracy: 0.9750
# Epoch 123/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0082 - accuracy: 0.9984 - val_loss: 0.1166 - val_accuracy: 0.9679
# Epoch 124/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0081 - accuracy: 0.9976 - val_loss: 0.1187 - val_accuracy: 0.9714
# Epoch 125/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0074 - accuracy: 0.9978 - val_loss: 0.1158 - val_accuracy: 0.9732
# Epoch 126/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0077 - accuracy: 0.9988 - val_loss: 0.1168 - val_accuracy: 0.9768
# Epoch 127/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0074 - accuracy: 0.9986 - val_loss: 0.1144 - val_accuracy: 0.9750
# Epoch 128/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0079 - accuracy: 0.9980 - val_loss: 0.1155 - val_accuracy: 0.9750
# Epoch 129/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0100 - accuracy: 0.9978 - val_loss: 0.1206 - val_accuracy: 0.9732
# Epoch 130/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0074 - accuracy: 0.9978 - val_loss: 0.1184 - val_accuracy: 0.9732
# Epoch 131/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0083 - accuracy: 0.9984 - val_loss: 0.1222 - val_accuracy: 0.9679
# Epoch 132/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0084 - accuracy: 0.9984 - val_loss: 0.1156 - val_accuracy: 0.9750
# Epoch 133/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0089 - accuracy: 0.9974 - val_loss: 0.1183 - val_accuracy: 0.9732
# Epoch 134/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0093 - accuracy: 0.9972 - val_loss: 0.1197 - val_accuracy: 0.9732
# Epoch 135/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0068 - accuracy: 0.9980 - val_loss: 0.1209 - val_accuracy: 0.9714
# Epoch 136/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0067 - accuracy: 0.9984 - val_loss: 0.1155 - val_accuracy: 0.9750
# Epoch 137/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0056 - accuracy: 0.9990 - val_loss: 0.1140 - val_accuracy: 0.9732
# Epoch 138/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0074 - accuracy: 0.9982 - val_loss: 0.1141 - val_accuracy: 0.9732
# Epoch 139/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0062 - accuracy: 0.9984 - val_loss: 0.1135 - val_accuracy: 0.9768
# Epoch 140/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0063 - accuracy: 0.9988 - val_loss: 0.1185 - val_accuracy: 0.9750
# Epoch 141/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0084 - accuracy: 0.9980 - val_loss: 0.1184 - val_accuracy: 0.9714
# Epoch 142/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0078 - accuracy: 0.9982 - val_loss: 0.1184 - val_accuracy: 0.9732
# Epoch 143/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0067 - accuracy: 0.9982 - val_loss: 0.1221 - val_accuracy: 0.9696
# Epoch 144/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0056 - accuracy: 0.9984 - val_loss: 0.1166 - val_accuracy: 0.9750
# Epoch 145/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0070 - accuracy: 0.9980 - val_loss: 0.1195 - val_accuracy: 0.9714
# Epoch 146/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0078 - accuracy: 0.9978 - val_loss: 0.1156 - val_accuracy: 0.9714
# Epoch 147/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0073 - accuracy: 0.9980 - val_loss: 0.1150 - val_accuracy: 0.9750
# Epoch 148/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0103 - accuracy: 0.9978 - val_loss: 0.1176 - val_accuracy: 0.9732
# Epoch 149/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0068 - accuracy: 0.9978 - val_loss: 0.1168 - val_accuracy: 0.9732
# Epoch 150/150
# 5040/5040 [==============================] - 27s 5ms/step - loss: 0.0063 - accuracy: 0.9988 - val_loss: 0.1166 - val_accuracy: 0.9696
# Saved model to disk

# %%
model = tf.keras.models.load_model("CNN2.model")
hsv_lower = np.array([0, 150, 150])
hsv_upper = np.array([10, 255, 255])


def test(originalFileName, testFileName, required_size=(IMG_SIZE, IMG_SIZE)):
  origin = cv2.imread(originalFileName)
  temp = cv2.imread(testFileName)
  difference = cv2.bitwise_xor(origin, temp, mask=None)
  Conv_hsv_Gray = cv2.cvtColor(difference, cv2.COLOR_BGR2GRAY)
  ret, mask = cv2.threshold(Conv_hsv_Gray, 0, 
                            255, cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)
  difference[mask != 255] = [0, 0, 255]
  origin[mask != 255] = [0, 0, 255]
  temp[mask != 255] = [0, 0, 255]
  hsv = cv2.cvtColor(origin, cv2.COLOR_BGR2HSV)
  mask = cv2.inRange(hsv, hsv_lower, hsv_upper)
  kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (3, 3))
  opening = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernel, iterations=1)
  close = cv2.morphologyEx(opening, cv2.MORPH_CLOSE, kernel, iterations=1)
  cnts = cv2.findContours(close, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
  cnts = cnts[0] if len(cnts) == 2 else cnts[1]
  offset = 20
  ROI_number = 0
  for c in cnts:
    x, y, w, h = cv2.boundingRect(c)
    ROI = origin[y - offset:y + h + offset, x - offset:x + w + offset]
    try:
      ROI = cv2.resize(ROI, (IMG_SIZE, IMG_SIZE))
      ROI = ROI.reshape(-1, IMG_SIZE, IMG_SIZE, 3)
      prediction = model.predict([ROI])
      prediction = list(prediction[0])
      if prediction.index(max(prediction)) != 1:
        cv2.rectangle(temp, (x - offset, y - offset), 
                    (x + w + offset, y + h + offset), (36, 255, 12), 2)
        cv2.putText(temp,CATEGORIES[prediction.index(max(prediction))],
                (x - offset, y - offset), 0, 1, 
                (255, 0, 255),2, cv2.LINE_AA)
    except cv2.error as e:
      ROI_number += 1
    ROI_number += 1
  plt.imshow(temp) 
  plt.show()

# %%
test('temp.jpg', 'test.jpg')

# %%
test('temp1.jpg', 'test1.jpg')

# %%
test('temp2.jpg', 'test2.jpg')

# %%
test('temp3.jpg', 'test3.jpg')

# %%
test('temp4.jpg', 'test4.jpg')
