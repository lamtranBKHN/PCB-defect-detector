# %% [markdown]
# <a href="https://colab.research.google.com/github/lamtranBKHN/PCB-defect-detector/blob/master/(80%2C80%2C3)VGG16_5600dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from imutils import paths
from keras.applications import VGG16
from keras.applications import imagenet_utils
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import load_img
from keras.optimizers import SGD
from keras.optimizers import RMSprop
from keras.layers import Input
from keras.models import Model
from keras.models import Sequential
from keras.layers.core import Dense
from keras.layers.core import Dropout
from keras.layers.core import Flatten
import numpy as np
import random
import os
from matplotlib import pyplot
from PIL import Image
from numpy import asarray
from matplotlib import pyplot as plt
import cv2
import pickle
# Out:
# Using TensorFlow backend.

# %%
IMG_SIZE = 80

file_list = []
class_list = []

DATADIR = "Organized dataSet"

# All the categories neural network will detect
CATEGORIES = ["mouse bite","not","open","pin hole",
              "short","spur","spurious copper"]

# Checking or all images in the data folder
for category in CATEGORIES :
    path = os.path.join(DATADIR, category)
    for img in os.listdir(path):
        img_array = cv2.imread(os.path.join(path, img), cv2.IMREAD_COLOR)

training_data = []

def create_training_data():
    for category in CATEGORIES :
        path = os.path.join(DATADIR, category)
        class_num = CATEGORIES.index(category)
        for img in os.listdir(path):
            try :
                img_array = cv2.imread(os.path.join(path, img), cv2.IMREAD_COLOR)
                new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
                training_data.append([new_array, class_num])
            except Exception as e:
                pass

create_training_data()
random.shuffle(training_data)

X = [] #features
y = [] #labels

for features, label in training_data:
    X.append(features)
    y.append(label)
    
X = np.array(X).reshape(-1, IMG_SIZE, IMG_SIZE, 3)   
# Creating the files containing all the information about your model
pickle_out = open("X.pickle", "wb")
pickle.dump(X, pickle_out)
pickle_out.close()

pickle_out = open("y.pickle", "wb")
pickle.dump(y, pickle_out)
pickle_out.close()

pickle_in = open("X.pickle", "rb")
X = pickle.load(pickle_in)

# Opening the files about data
X = pickle.load(open("X.pickle", "rb"))
y = pickle.load(open("y.pickle", "rb"))

# normalizing data (a pixel goes from 0 to 255)
X = X/255.0

# %%
# Load model VGG 16 
baseModel = VGG16(weights='imagenet', include_top=False, \
                  input_tensor=Input(shape=(IMG_SIZE, IMG_SIZE, 3)))
# Buil layer
fcHead = baseModel.output
# Flatten 
fcHead = Flatten()(fcHead)
# Add FC
fcHead = Dense(512, activation='relu')(fcHead)
fcHead = Dropout(0.3)(fcHead)
# Output layer with softmax activation
fcHead = Dense(7, activation='softmax')(fcHead)
# modle
model = model = Model(inputs=baseModel.input, outputs=fcHead)
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 2s 0us/step

# %%
model.compile(loss = "sparse_categorical_crossentropy", 
                    optimizer = SGD(lr=1e-5, momentum=0.9), 
                    metrics=["accuracy"])
# Training the model.
X = np.array(X)
y = np.array(y)
history = model.fit(X, y, batch_size=32, epochs=120, validation_split=0.1)

# Saving the model
model_json = model.to_json()
with open("model.json", "w") as json_file :
    json_file.write(model_json)

model.save_weights("model2.h5")
print("Saved model to disk")

model.save('CNN2.model')

# Printing a graph showing the accuracy changes during the training phase
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'b', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()
# Out:
# Train on 5040 samples, validate on 560 samples
# Epoch 1/150
# 5040/5040 [==============================] - 22s 4ms/step - loss: 1.9484 - accuracy: 0.2123 - val_loss: 1.6775 - val_accuracy: 0.4857
# Epoch 2/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 1.6067 - accuracy: 0.4149 - val_loss: 1.3607 - val_accuracy: 0.6946
# Epoch 3/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 1.3126 - accuracy: 0.5399 - val_loss: 1.0532 - val_accuracy: 0.7732
# Epoch 4/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 1.0260 - accuracy: 0.6639 - val_loss: 0.7651 - val_accuracy: 0.8339
# Epoch 5/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.7853 - accuracy: 0.7401 - val_loss: 0.5550 - val_accuracy: 0.8625
# Epoch 6/150
# 5040/5040 [==============================] - 14s 3ms/step - loss: 0.6038 - accuracy: 0.8069 - val_loss: 0.4173 - val_accuracy: 0.8839
# Epoch 7/150
# 5040/5040 [==============================] - 14s 3ms/step - loss: 0.4907 - accuracy: 0.8355 - val_loss: 0.3437 - val_accuracy: 0.8946
# Epoch 8/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.4247 - accuracy: 0.8579 - val_loss: 0.3006 - val_accuracy: 0.9089
# Epoch 9/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.3562 - accuracy: 0.8827 - val_loss: 0.2699 - val_accuracy: 0.9161
# Epoch 10/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.3204 - accuracy: 0.9028 - val_loss: 0.2335 - val_accuracy: 0.9268
# Epoch 11/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.2760 - accuracy: 0.9115 - val_loss: 0.2094 - val_accuracy: 0.9339
# Epoch 12/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.2563 - accuracy: 0.9210 - val_loss: 0.1951 - val_accuracy: 0.9411
# Epoch 13/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.2370 - accuracy: 0.9250 - val_loss: 0.1841 - val_accuracy: 0.9393
# Epoch 14/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.2125 - accuracy: 0.9343 - val_loss: 0.1813 - val_accuracy: 0.9357
# Epoch 15/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.1992 - accuracy: 0.9407 - val_loss: 0.1646 - val_accuracy: 0.9482
# Epoch 16/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.1895 - accuracy: 0.9438 - val_loss: 0.1554 - val_accuracy: 0.9536
# Epoch 17/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.1730 - accuracy: 0.9438 - val_loss: 0.1550 - val_accuracy: 0.9518
# Epoch 18/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.1695 - accuracy: 0.9502 - val_loss: 0.1450 - val_accuracy: 0.9536
# Epoch 19/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.1508 - accuracy: 0.9532 - val_loss: 0.1394 - val_accuracy: 0.9554
# Epoch 20/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.1461 - accuracy: 0.9536 - val_loss: 0.1343 - val_accuracy: 0.9607
# Epoch 21/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.1354 - accuracy: 0.9587 - val_loss: 0.1335 - val_accuracy: 0.9589
# Epoch 22/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.1242 - accuracy: 0.9619 - val_loss: 0.1230 - val_accuracy: 0.9625
# Epoch 23/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.1206 - accuracy: 0.9647 - val_loss: 0.1203 - val_accuracy: 0.9625
# Epoch 24/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.1084 - accuracy: 0.9671 - val_loss: 0.1194 - val_accuracy: 0.9661
# Epoch 25/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.1050 - accuracy: 0.9700 - val_loss: 0.1155 - val_accuracy: 0.9696
# Epoch 26/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.1013 - accuracy: 0.9677 - val_loss: 0.1148 - val_accuracy: 0.9696
# Epoch 27/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0991 - accuracy: 0.9708 - val_loss: 0.1113 - val_accuracy: 0.9696
# Epoch 28/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0890 - accuracy: 0.9730 - val_loss: 0.1093 - val_accuracy: 0.9679
# Epoch 29/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0911 - accuracy: 0.9736 - val_loss: 0.1126 - val_accuracy: 0.9714
# Epoch 30/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0848 - accuracy: 0.9744 - val_loss: 0.1007 - val_accuracy: 0.9732
# Epoch 31/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0788 - accuracy: 0.9754 - val_loss: 0.1037 - val_accuracy: 0.9732
# Epoch 32/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0835 - accuracy: 0.9760 - val_loss: 0.0971 - val_accuracy: 0.9750
# Epoch 33/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0782 - accuracy: 0.9782 - val_loss: 0.0931 - val_accuracy: 0.9714
# Epoch 34/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0682 - accuracy: 0.9788 - val_loss: 0.0945 - val_accuracy: 0.9750
# Epoch 35/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0678 - accuracy: 0.9806 - val_loss: 0.0938 - val_accuracy: 0.9750
# Epoch 36/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0709 - accuracy: 0.9778 - val_loss: 0.0912 - val_accuracy: 0.9750
# Epoch 37/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0674 - accuracy: 0.9798 - val_loss: 0.0949 - val_accuracy: 0.9750
# Epoch 38/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0667 - accuracy: 0.9802 - val_loss: 0.0866 - val_accuracy: 0.9768
# Epoch 39/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0578 - accuracy: 0.9849 - val_loss: 0.0886 - val_accuracy: 0.9768
# Epoch 40/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0600 - accuracy: 0.9810 - val_loss: 0.0879 - val_accuracy: 0.9768
# Epoch 41/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0561 - accuracy: 0.9833 - val_loss: 0.0876 - val_accuracy: 0.9768
# Epoch 42/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0525 - accuracy: 0.9847 - val_loss: 0.0832 - val_accuracy: 0.9768
# Epoch 43/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0519 - accuracy: 0.9853 - val_loss: 0.0880 - val_accuracy: 0.9786
# Epoch 44/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0471 - accuracy: 0.9845 - val_loss: 0.0890 - val_accuracy: 0.9786
# Epoch 45/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0501 - accuracy: 0.9837 - val_loss: 0.0816 - val_accuracy: 0.9768
# Epoch 46/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0488 - accuracy: 0.9865 - val_loss: 0.0801 - val_accuracy: 0.9804
# Epoch 47/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0477 - accuracy: 0.9863 - val_loss: 0.0843 - val_accuracy: 0.9804
# Epoch 48/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0450 - accuracy: 0.9877 - val_loss: 0.0836 - val_accuracy: 0.9804
# Epoch 49/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0463 - accuracy: 0.9865 - val_loss: 0.0851 - val_accuracy: 0.9804
# Epoch 50/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0405 - accuracy: 0.9883 - val_loss: 0.0834 - val_accuracy: 0.9768
# Epoch 51/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0423 - accuracy: 0.9881 - val_loss: 0.0801 - val_accuracy: 0.9786
# Epoch 52/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0410 - accuracy: 0.9891 - val_loss: 0.0819 - val_accuracy: 0.9786
# Epoch 53/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0387 - accuracy: 0.9889 - val_loss: 0.0787 - val_accuracy: 0.9821
# Epoch 54/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0373 - accuracy: 0.9899 - val_loss: 0.0758 - val_accuracy: 0.9786
# Epoch 55/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0343 - accuracy: 0.9907 - val_loss: 0.0735 - val_accuracy: 0.9768
# Epoch 56/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0368 - accuracy: 0.9887 - val_loss: 0.0779 - val_accuracy: 0.9821
# Epoch 57/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0353 - accuracy: 0.9899 - val_loss: 0.0763 - val_accuracy: 0.9804
# Epoch 58/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0312 - accuracy: 0.9915 - val_loss: 0.0809 - val_accuracy: 0.9804
# Epoch 59/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0328 - accuracy: 0.9909 - val_loss: 0.0780 - val_accuracy: 0.9804
# Epoch 60/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0340 - accuracy: 0.9907 - val_loss: 0.0779 - val_accuracy: 0.9804
# Epoch 61/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0266 - accuracy: 0.9937 - val_loss: 0.0811 - val_accuracy: 0.9821
# Epoch 62/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0293 - accuracy: 0.9927 - val_loss: 0.0720 - val_accuracy: 0.9786
# Epoch 63/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0309 - accuracy: 0.9915 - val_loss: 0.0802 - val_accuracy: 0.9804
# Epoch 64/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0285 - accuracy: 0.9921 - val_loss: 0.0788 - val_accuracy: 0.9839
# Epoch 65/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0300 - accuracy: 0.9917 - val_loss: 0.0770 - val_accuracy: 0.9786
# Epoch 66/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0282 - accuracy: 0.9919 - val_loss: 0.0748 - val_accuracy: 0.9804
# Epoch 67/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0266 - accuracy: 0.9935 - val_loss: 0.0732 - val_accuracy: 0.9804
# Epoch 68/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0259 - accuracy: 0.9937 - val_loss: 0.0717 - val_accuracy: 0.9839
# Epoch 69/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0256 - accuracy: 0.9921 - val_loss: 0.0806 - val_accuracy: 0.9804
# Epoch 70/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0222 - accuracy: 0.9942 - val_loss: 0.0745 - val_accuracy: 0.9804
# Epoch 71/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0218 - accuracy: 0.9940 - val_loss: 0.0749 - val_accuracy: 0.9786
# Epoch 72/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0236 - accuracy: 0.9933 - val_loss: 0.0741 - val_accuracy: 0.9786
# Epoch 73/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0228 - accuracy: 0.9938 - val_loss: 0.0760 - val_accuracy: 0.9804
# Epoch 74/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0207 - accuracy: 0.9954 - val_loss: 0.0732 - val_accuracy: 0.9804
# Epoch 75/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0219 - accuracy: 0.9944 - val_loss: 0.0749 - val_accuracy: 0.9786
# Epoch 76/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0236 - accuracy: 0.9935 - val_loss: 0.0730 - val_accuracy: 0.9804
# Epoch 77/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0195 - accuracy: 0.9948 - val_loss: 0.0783 - val_accuracy: 0.9804
# Epoch 78/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0221 - accuracy: 0.9946 - val_loss: 0.0732 - val_accuracy: 0.9804
# Epoch 79/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0201 - accuracy: 0.9946 - val_loss: 0.0731 - val_accuracy: 0.9821
# Epoch 80/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0208 - accuracy: 0.9944 - val_loss: 0.0724 - val_accuracy: 0.9786
# Epoch 81/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0187 - accuracy: 0.9946 - val_loss: 0.0783 - val_accuracy: 0.9786
# Epoch 82/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0216 - accuracy: 0.9921 - val_loss: 0.0821 - val_accuracy: 0.9821
# Epoch 83/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0184 - accuracy: 0.9962 - val_loss: 0.0740 - val_accuracy: 0.9804
# Epoch 84/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0179 - accuracy: 0.9952 - val_loss: 0.0732 - val_accuracy: 0.9804
# Epoch 85/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0168 - accuracy: 0.9952 - val_loss: 0.0707 - val_accuracy: 0.9786
# Epoch 86/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0158 - accuracy: 0.9952 - val_loss: 0.0694 - val_accuracy: 0.9804
# Epoch 87/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0146 - accuracy: 0.9960 - val_loss: 0.0712 - val_accuracy: 0.9804
# Epoch 88/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0155 - accuracy: 0.9956 - val_loss: 0.0724 - val_accuracy: 0.9804
# Epoch 89/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0159 - accuracy: 0.9958 - val_loss: 0.0719 - val_accuracy: 0.9786
# Epoch 90/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0137 - accuracy: 0.9962 - val_loss: 0.0731 - val_accuracy: 0.9786
# Epoch 91/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0128 - accuracy: 0.9960 - val_loss: 0.0773 - val_accuracy: 0.9768
# Epoch 92/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0170 - accuracy: 0.9942 - val_loss: 0.0816 - val_accuracy: 0.9786
# Epoch 93/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0122 - accuracy: 0.9974 - val_loss: 0.0718 - val_accuracy: 0.9804
# Epoch 94/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0153 - accuracy: 0.9950 - val_loss: 0.0693 - val_accuracy: 0.9821
# Epoch 95/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0135 - accuracy: 0.9964 - val_loss: 0.0736 - val_accuracy: 0.9821
# Epoch 96/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0123 - accuracy: 0.9968 - val_loss: 0.0756 - val_accuracy: 0.9821
# Epoch 97/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0143 - accuracy: 0.9960 - val_loss: 0.0782 - val_accuracy: 0.9804
# Epoch 98/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0118 - accuracy: 0.9972 - val_loss: 0.0758 - val_accuracy: 0.9786
# Epoch 99/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0151 - accuracy: 0.9960 - val_loss: 0.0774 - val_accuracy: 0.9786
# Epoch 100/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0121 - accuracy: 0.9978 - val_loss: 0.0750 - val_accuracy: 0.9821
# Epoch 101/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0133 - accuracy: 0.9958 - val_loss: 0.0761 - val_accuracy: 0.9804
# Epoch 102/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0125 - accuracy: 0.9970 - val_loss: 0.0748 - val_accuracy: 0.9786
# Epoch 103/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0147 - accuracy: 0.9960 - val_loss: 0.0764 - val_accuracy: 0.9821
# Epoch 104/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0125 - accuracy: 0.9966 - val_loss: 0.0766 - val_accuracy: 0.9821
# Epoch 105/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0111 - accuracy: 0.9972 - val_loss: 0.0714 - val_accuracy: 0.9821
# Epoch 106/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0106 - accuracy: 0.9976 - val_loss: 0.0672 - val_accuracy: 0.9804
# Epoch 107/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0125 - accuracy: 0.9960 - val_loss: 0.0755 - val_accuracy: 0.9804
# Epoch 108/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0113 - accuracy: 0.9970 - val_loss: 0.0718 - val_accuracy: 0.9804
# Epoch 109/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0120 - accuracy: 0.9968 - val_loss: 0.0755 - val_accuracy: 0.9821
# Epoch 110/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0122 - accuracy: 0.9970 - val_loss: 0.0770 - val_accuracy: 0.9804
# Epoch 111/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0111 - accuracy: 0.9964 - val_loss: 0.0707 - val_accuracy: 0.9786
# Epoch 112/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0119 - accuracy: 0.9964 - val_loss: 0.0754 - val_accuracy: 0.9804
# Epoch 113/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0137 - accuracy: 0.9962 - val_loss: 0.0718 - val_accuracy: 0.9804
# Epoch 114/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0083 - accuracy: 0.9978 - val_loss: 0.0699 - val_accuracy: 0.9750
# Epoch 115/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0105 - accuracy: 0.9968 - val_loss: 0.0737 - val_accuracy: 0.9786
# Epoch 116/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0119 - accuracy: 0.9974 - val_loss: 0.0717 - val_accuracy: 0.9821
# Epoch 117/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0080 - accuracy: 0.9982 - val_loss: 0.0815 - val_accuracy: 0.9821
# Epoch 118/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0109 - accuracy: 0.9978 - val_loss: 0.0739 - val_accuracy: 0.9786
# Epoch 119/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0097 - accuracy: 0.9976 - val_loss: 0.0723 - val_accuracy: 0.9786
# Epoch 120/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0076 - accuracy: 0.9988 - val_loss: 0.0710 - val_accuracy: 0.9804
# Epoch 121/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0112 - accuracy: 0.9978 - val_loss: 0.0710 - val_accuracy: 0.9786
# Epoch 122/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0100 - accuracy: 0.9974 - val_loss: 0.0675 - val_accuracy: 0.9821
# Epoch 123/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0120 - accuracy: 0.9966 - val_loss: 0.0709 - val_accuracy: 0.9821
# Epoch 124/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0106 - accuracy: 0.9972 - val_loss: 0.0755 - val_accuracy: 0.9821
# Epoch 125/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0113 - accuracy: 0.9962 - val_loss: 0.0705 - val_accuracy: 0.9821
# Epoch 126/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0076 - accuracy: 0.9982 - val_loss: 0.0681 - val_accuracy: 0.9821
# Epoch 127/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0092 - accuracy: 0.9976 - val_loss: 0.0674 - val_accuracy: 0.9821
# Epoch 128/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0071 - accuracy: 0.9984 - val_loss: 0.0753 - val_accuracy: 0.9821
# Epoch 129/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0081 - accuracy: 0.9978 - val_loss: 0.0788 - val_accuracy: 0.9768
# Epoch 130/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0091 - accuracy: 0.9970 - val_loss: 0.0726 - val_accuracy: 0.9839
# Epoch 131/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0087 - accuracy: 0.9974 - val_loss: 0.0668 - val_accuracy: 0.9839
# Epoch 132/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0095 - accuracy: 0.9976 - val_loss: 0.0811 - val_accuracy: 0.9821
# Epoch 133/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0073 - accuracy: 0.9988 - val_loss: 0.0768 - val_accuracy: 0.9804
# Epoch 134/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0095 - accuracy: 0.9970 - val_loss: 0.0830 - val_accuracy: 0.9839
# Epoch 135/150
# 5040/5040 [==============================] - 14s 3ms/step - loss: 0.0093 - accuracy: 0.9980 - val_loss: 0.0784 - val_accuracy: 0.9786
# Epoch 136/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0086 - accuracy: 0.9980 - val_loss: 0.0718 - val_accuracy: 0.9804
# Epoch 137/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0080 - accuracy: 0.9974 - val_loss: 0.0791 - val_accuracy: 0.9821
# Epoch 138/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0074 - accuracy: 0.9988 - val_loss: 0.0723 - val_accuracy: 0.9839
# Epoch 139/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0079 - accuracy: 0.9986 - val_loss: 0.0779 - val_accuracy: 0.9821
# Epoch 140/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0064 - accuracy: 0.9980 - val_loss: 0.0773 - val_accuracy: 0.9821
# Epoch 141/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0085 - accuracy: 0.9976 - val_loss: 0.0708 - val_accuracy: 0.9821
# Epoch 142/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0067 - accuracy: 0.9982 - val_loss: 0.0689 - val_accuracy: 0.9821
# Epoch 143/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0109 - accuracy: 0.9966 - val_loss: 0.0727 - val_accuracy: 0.9821
# Epoch 144/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0071 - accuracy: 0.9982 - val_loss: 0.0670 - val_accuracy: 0.9839
# Epoch 145/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0062 - accuracy: 0.9984 - val_loss: 0.0768 - val_accuracy: 0.9821
# Epoch 146/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0085 - accuracy: 0.9968 - val_loss: 0.0735 - val_accuracy: 0.9821
# Epoch 147/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0093 - accuracy: 0.9980 - val_loss: 0.0681 - val_accuracy: 0.9839
# Epoch 148/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0067 - accuracy: 0.9982 - val_loss: 0.0746 - val_accuracy: 0.9821
# Epoch 149/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0067 - accuracy: 0.9990 - val_loss: 0.0779 - val_accuracy: 0.9821
# Epoch 150/150
# 5040/5040 [==============================] - 13s 3ms/step - loss: 0.0068 - accuracy: 0.9986 - val_loss: 0.0764 - val_accuracy: 0.9821
# Saved model to disk

# %%
model = tf.keras.models.load_model("CNN2.model")
hsv_lower = np.array([0, 150, 150])
hsv_upper = np.array([10, 255, 255])


def test(originalFileName, testFileName, required_size=(IMG_SIZE, IMG_SIZE)):
  origin = cv2.imread(originalFileName)
  temp = cv2.imread(testFileName)
  difference = cv2.bitwise_xor(origin, temp, mask=None)
  Conv_hsv_Gray = cv2.cvtColor(difference, cv2.COLOR_BGR2GRAY)
  ret, mask = cv2.threshold(Conv_hsv_Gray, 0, 
                            255, cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)
  difference[mask != 255] = [0, 0, 255]
  origin[mask != 255] = [0, 0, 255]
  temp[mask != 255] = [0, 0, 255]
  hsv = cv2.cvtColor(origin, cv2.COLOR_BGR2HSV)
  mask = cv2.inRange(hsv, hsv_lower, hsv_upper)
  kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (3, 3))
  opening = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernel, iterations=1)
  close = cv2.morphologyEx(opening, cv2.MORPH_CLOSE, kernel, iterations=1)
  cnts = cv2.findContours(close, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
  cnts = cnts[0] if len(cnts) == 2 else cnts[1]
  offset = 20
  ROI_number = 0
  for c in cnts:
    x, y, w, h = cv2.boundingRect(c)
    ROI = origin[y - offset:y + h + offset, x - offset:x + w + offset]
    ROI = cv2.resize(ROI, (IMG_SIZE, IMG_SIZE))
    ROI = ROI.reshape(-1, IMG_SIZE, IMG_SIZE, 3)
    prediction = model.predict([ROI])
    prediction = list(prediction[0])
    if prediction.index(max(prediction)) != 1:
      cv2.rectangle(temp, (x - offset, y - offset), 
                    (x + w + offset, y + h + offset), (36, 255, 12), 2)
      cv2.putText(temp,CATEGORIES[prediction.index(max(prediction))],
                (x - offset, y - offset), 0, 1, 
                (255, 0, 255),2, cv2.LINE_AA)
    ROI_number += 1
  plt.imshow(temp) 
  plt.show()

# %%
test('temp.jpg', 'test.jpg')
